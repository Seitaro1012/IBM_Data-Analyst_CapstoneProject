# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# データワラを分析するためのデータセットを準備するための重要なステップであり、重複を処理することは、データの正確性を確保する上で重要な役割を果たします。このラボでは、データセットから重複したエントリの識別と削除に焦点を当てます。

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# 1.データセット内の重複行を特定し、その特性を分析します。
# 2。重要な属性に基づいて、重複の分布を視覚化します。
# 3.特定の基準に基づいて、重複した値を戦略的に削除します。
# 4.重複除去の検証と文書化のプロセスの概要。

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %% [markdown]
# 注：ローカルJupyter環境に取り組んでいる場合は、以下に示すようにPandas.read_csv（）関数でURLを直接使用できます。

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %% [markdown]
# ### タスク1：重複する行を特定します
# 1.データセット内の重複行の数をカウントします。
# 3。構造を理解するために、最初のいくつかの重複行を表示します。

# %%
## Write your code here

##... existing code ...
## Write your code here
# Count total duplicate rows
duplicate_rows = df[df.duplicated()]
print(f"Total number of duplicate rows: {len(duplicate_rows)}")

# Display first few duplicate rows
print("\nFirst few duplicate rows:")
duplicate_rows.head()
##... existing code ...
# Out:
# Total number of duplicate rows: 20
#
# First few duplicate rows:
#        ResponseId                      MainBranch                 Age  \
# 65437           1  I am a developer by profession  Under 18 years old
# 65438           2  I am a developer by profession     35-44 years old
# 65439           3  I am a developer by profession     45-54 years old
# 65440           4           I am learning to code     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 65437  Employed, full-time     Remote  Apples
# 65438  Employed, full-time     Remote  Apples
# 65439  Employed, full-time     Remote  Apples
# 65440   Student, full-time        NaN  Apples
# 65441   Student, full-time        NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %% [markdown]
# ### タスク2：重複の特性を分析します
# 1. Mainbranch、雇用、リモートワークなどの選択した列に基づいて、重複する行を特定します。
# これらの複製行内に頻繁に同一の値が含まれる列を分析します。
# 2。メインブランチ、雇用、リモートワークなどの列のサブセットに基づいて、重複している行の特性を分析します。
# これらの行全体で頻繁に同一の値がある列を決定します。

# %%
## Write your code here

# // ... existing code ...
## Write your code here
# Define columns to check for duplicates
columns_to_check = ['MainBranch', 'Employment', 'RemoteWork']

# Find duplicates based on selected columns
duplicates_subset = df[df.duplicated(subset=columns_to_check, keep=False)]
print(f"Number of rows with duplicate values in {columns_to_check}: {len(duplicates_subset)}")

# Analyze which columns frequently have identical values
print("\nFrequency of identical values in duplicate rows:")
for col in df.columns:
    if col not in columns_to_check:
        identical_count = duplicates_subset.groupby(columns_to_check)[col].apply(lambda x: x.nunique() == 1).sum()
        print(f"{col}: {identical_count} groups with identical values")
# // ... existing code ...
# Out:
# Number of rows with duplicate values in ['MainBranch', 'Employment', 'RemoteWork']: 65290
#
# Frequency of identical values in duplicate rows:
# ResponseId: 0 groups with identical values
# Age: 30 groups with identical values
# Check: 319 groups with identical values
# CodingActivities: 1 groups with identical values
# EdLevel: 23 groups with identical values
# LearnCode: 12 groups with identical values
# LearnCodeOnline: 33 groups with identical values
# TechDoc: 58 groups with identical values
# YearsCode: 13 groups with identical values
# YearsCodePro: 8 groups with identical values
# DevType: 18 groups with identical values
# OrgSize: 20 groups with identical values
# PurchaseInfluence: 28 groups with identical values
# BuyNewTool: 7 groups with identical values
# BuildvsBuy: 31 groups with identical values
# TechEndorse: 8 groups with identical values
# Country: 19 groups with identical values
# Currency: 10 groups with identical values
# ...

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %% [markdown]
# ###  タスク3：視覚化複製分布を視覚化します
# 1.さまざまなカテゴリにわたって重複の分布を示す視覚化を作成します。
# 2.バーチャートまたはパイチャートを使用して、国と雇用による重複の分布を表します。

# %%
## Write your code here

# // ... existing code ...
## Write your code here
# Set up the figure
plt.figure(figsize=(20, 10))

# Plot 1: Distribution by Country
plt.subplot(1, 2, 1)
duplicate_countries = df[df.duplicated()]['Country'].value_counts().head(10)
duplicate_countries.plot(kind='bar')
plt.title('Top 10 Countries with Duplicates')
plt.xlabel('Country')
plt.ylabel('Number of Duplicates')
plt.xticks(rotation=45)

# Plot 2: Distribution by Employment
plt.subplot(1, 2, 2)
duplicate_employment = df[df.duplicated()]['Employment'].value_counts()
duplicate_employment.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Duplicates by Employment')

plt.tight_layout()
plt.show()
# // ... existing code ...

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %% [markdown]
# ###  タスク4：重複の戦略的除去
# 1.データセットの一意性を定義するために重要な列を決定します。
# 2.完全な行の複製が適切な基準ではない場合は、列のサブセットに基づいて複製を削除します。

# %%
## Write your code here

# // ... existing code ...
## Write your code here
# Define columns that determine uniqueness
unique_columns = ['MainBranch', 'Employment', 'RemoteWork', 'Country']

# Remove duplicates keeping the first occurrence
df_cleaned = df.drop_duplicates(subset=unique_columns, keep='first')

print(f"Original dataset shape: {df.shape}")
print(f"Cleaned dataset shape: {df_cleaned.shape}")
print(f"Number of rows removed: {len(df) - len(df_cleaned)}")

# Display sample of removed duplicates
removed_duplicates = df[df.duplicated(subset=unique_columns, keep=False)]
print("\nSample of removed duplicates:")
removed_duplicates.head()
# // ... existing code ...
# Out:
# Original dataset shape: (65457, 114)
# Cleaned dataset shape: (6941, 114)
# Number of rows removed: 58516
#
# Sample of removed duplicates:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# ```
# Regarding the process of identifying and removing duplicates:
#
# 1.  **Loading the dataset and checking basic information:**
#     -   The shape, data types, and missing values of the dataset were checked.
#     -   This allowed for an understanding of the overall data structure.
#
# 2.  **Identifying duplicate rows:**
#     -   The `duplicated()` method was used to identify complete duplicate rows.
#     -   The total number of duplicate rows and the first few rows were displayed for confirmation.
#
# 3.  **Analyzing duplicates:**
#     -   Duplicates were analyzed based on the 'MainBranch', 'Employment', and 'RemoteWork' columns.
#     -   The identicality of values in each column was checked to identify which columns frequently had duplicates.
#
# 4.  **Visualization:**
#     -   The distribution of duplicates by country was displayed using a bar chart.
#     -   The distribution of duplicates by employment type was displayed using a pie chart.
#     -   This provided a visual understanding of duplicate patterns.
#
# 5.  **Removing duplicates:**
#     -   Duplicates were removed based on important columns ('MainBranch', 'Employment', 'RemoteWork', 'Country').
#     -   The first occurrence was kept, and subsequent duplicates were removed.
#     -   The dataset size before and after removal was compared for confirmation.
# ```

# %% [markdown]
# ###  タスク5：ドキュメント
# 1.重複を識別および削除するプロセスを文書化します。

# %% [raw]
# 重複の特定と削除プロセスについて：
#
# 1. データセットの読み込みと基本情報の確認
#    - データセットの形状、データ型、欠損値の確認を行いました
#    - これにより、データの全体的な構造を理解しました
#
# 2. 重複行の特定
#    - duplicated()メソッドを使用して完全な重複行を特定
#    - 重複行の総数と最初の数行を表示して確認
#
# 3. 重複の分析
#    - MainBranch、Employment、RemoteWorkの列に基づいて重複を分析
#    - 各列の値の同一性を確認し、どの列が頻繁に重複しているかを特定
#
# 4. 可視化
#    - 国別の重複分布を棒グラフで表示
#    - 雇用形態別の重複分布を円グラフで表示
#    - これにより、重複のパターンを視覚的に理解
#
# 5. 重複の削除
#    - 重要な列（MainBranch、Employment、RemoteWork、Country）に基づいて重複を削除
#    - 最初の出現を保持し、その後の重複を削除
#    - 削除前後のデータセットサイズを比較して確認
# """

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# 1.  **Examine the dataset's basic information to understand the overall duplicate situation.**
# 2.  **Identify complete duplicate rows and comprehend their characteristics.**
# 3.  **Analyze duplicates based on specific columns to pinpoint patterns.**
# 4.  **Visualize the distribution of duplicates to deepen understanding.**
# 5.  **Strategically remove duplicates to enhance data quality.**

# %% [markdown]
# 2。重複を識別および削除するための特定の列の選択の背後にある理由を説明します。

# %% [raw]
# # Write your explanation here
#
# 1.データセットの基本情報を確認し、重複の全体的な状況を把握
# 2.完全な重複行を特定し、その特徴を理解
# 3.特定の列に基づいて重複を分析し、パターンを特定
# 4.重複の分布を視覚化して理解を深める
# 5.戦略的に重複を削除し、データの品質を向上

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
