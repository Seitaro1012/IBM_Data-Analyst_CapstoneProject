# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Histogram**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this lab, you will focus on the visualization of data. The dataset will be provided through an RDBMS, and you will need to use SQL queries to extract the required data.

# %% [markdown]
# このラボでは、データの視覚化に焦点を当てます。データセットはRDBMSを介して提供され、SQLクエリを使用して必要なデータを抽出する必要があります。

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Visualize the distribution of data using histograms.
#
# - Visualize relationships between features.
#
# - Explore data composition and comparisons.

# %% [markdown]
#  - ヒストグラムを使用してデータの分布を視覚化します。
#
#  - 機能間の関係を視覚化します。
#
#  - データ構成と比較を調べます。

# %% [markdown]
# ## Demo: Working with database

# %% [markdown]
# #### Download the database file.

# %%
# !wget -O survey-data.sqlite https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite
# Out:
# zsh:1: command not found: wget

# %% [markdown]
# #### Install the required libraries and import them

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import sqlite3
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
sns.set_palette("pastel")
sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 2.5})

# %%
import urllib.request

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite"
output_filename = "survey-data.sqlite"

try:
    urllib.request.urlretrieve(url, output_filename)
    print(f"ファイル '{output_filename}' をダウンロードしました。")

except urllib.error.URLError as e:
    print(f"ダウンロード中にエラーが発生しました: {e}")
# Out:
# ファイル 'survey-data.sqlite' をダウンロードしました。

# %% [markdown]
# #### Connect to the SQLite database

# %%
conn = sqlite3.connect('survey-data.sqlite')

# %% [markdown]
# ## Demo: Basic SQL queries
#
# **Demo 1: Count the number of rows in the table**

# %%
QUERY = "SELECT COUNT(*) FROM main"
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    COUNT(*)
# 0     65437

# %% [markdown]
# **Demo 2: List all tables**

# %%
QUERY = """
SELECT name as Table_Name 
FROM sqlite_master 
WHERE type = 'table'
"""
pd.read_sql_query(QUERY, conn)
# Out:
#   Table_Name
# 0       main

# %% [markdown]
# **Demo 3: Group data by age**

# %%
QUERY = """
SELECT Age, COUNT(*) as count 
FROM main 
GROUP BY Age 
ORDER BY Age
"""
df_age = pd.read_sql_query(QUERY, conn)
print(df_age)
# Out:
#                   Age  count
# 0     18-24 years old  14098
# 1     25-34 years old  23911
# 2     35-44 years old  14942
# 3     45-54 years old   6249
# 4     55-64 years old   2575
# 5   65 years or older    772
# 6   Prefer not to say    322
# 7  Under 18 years old   2568

# %% [markdown]
# ## Hands-on Lab: Visualizing Data with Histograms

# %% [markdown]
# ### 1. Visualizing the distribution of data (Histograms)

# %% [markdown]
# **1.1 Histogram of `CompTotal` (Total Compensation)**

# %% [markdown]
# Objective: Plot a histogram of `CompTotal` to visualize the distribution of respondents' total compensation.

# %% [markdown]
# 目的：「comptotal」のヒストグラムをプロットして、回答者の総報酬の分布を視覚化します。

# %%
## Write your code here

QUERY = """
SELECT CompTotal 
FROM main 
WHERE CompTotal IS NOT NULL
"""
df_comp = pd.read_sql_query(QUERY, conn)

plt.figure(figsize=(10, 6))
plt.hist(df_comp['CompTotal'], bins=50, edgecolor='black')
plt.title('Distribution of Total Compensation')
plt.xlabel('Total Compensation')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **1.2 Histogram of YearsCodePro (Years of Professional Coding Experience)**

# %% [markdown]
# Objective: Plot a histogram of `YearsCodePro` to analyze the distribution of coding experience among respondents.

# %% [markdown]
# 目的：「YearsCodepro」のヒストグラムをプロットして、回答者間のコーディングエクスペリエンスの分布を分析します。

# %%
## Write your code here

QUERY = """
SELECT YearsCodePro 
FROM main 
WHERE YearsCodePro IS NOT NULL
"""
df_years = pd.read_sql_query(QUERY, conn)

plt.figure(figsize=(15, 10))
plt.hist(df_years['YearsCodePro'], bins=30, edgecolor='black')
plt.title('Distribution of Years of Professional Coding Experience')
plt.xlabel('Years of Professional Coding')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### 2. Visualizing Relationships in Data

# %% [markdown]
# **2.1 Histogram Comparison of `CompTotal` by `Age` Group**

# %% [markdown]
# Objective: Use histograms to compare the distribution of CompTotal across different Age groups.

# %% [markdown]
# 目的：ヒストグラムを使用して、異なる年齢層にわたるコンポーテルの分布を比較します。

# %%
## Write your code here

QUERY = """
SELECT Age, CompTotal 
FROM main 
WHERE CompTotal IS NOT NULL AND Age IS NOT NULL
"""
df_age_comp = pd.read_sql_query(QUERY, conn)

plt.figure(figsize=(12, 8))
for age_group in df_age_comp['Age'].unique():
    data = df_age_comp[df_age_comp['Age'] == age_group]['CompTotal']
    plt.hist(data, bins=30, alpha=0.5, label=age_group)

plt.title('Distribution of Total Compensation by Age Group')
plt.xlabel('Total Compensation')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **2.2 Histogram of TimeSearching for Different Age Groups**

# %% [markdown]
# Objective: Use histograms to explore the distribution of `TimeSearching` (time spent searching for information) for respondents across different age groups.

# %% [markdown]
# 目的：ヒストグラムを使用して、さまざまな年齢層の回答者の「TimeSearch」（情報の検索に費やす時間）の分布を調査します。

# %%
## Write your code here


QUERY = """
SELECT Age, TimeSearching 
FROM main 
WHERE TimeSearching IS NOT NULL AND Age IS NOT NULL
"""
df_time = pd.read_sql_query(QUERY, conn)

plt.figure(figsize=(12, 8))
for age_group in df_time['Age'].unique():
    data = df_time[df_time['Age'] == age_group]['TimeSearching']
    plt.hist(data, bins=20, alpha=0.5, label=age_group)

plt.title('Distribution of Time Spent Searching by Age Group')
plt.xlabel('Time Spent Searching')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### 3. Visualizing the Composition of Data

# %% [markdown]
# **3.1 Histogram of Most Desired Databases (`DatabaseWantToWorkWith`)**

# %% [markdown]
# Objective: Visualize the most desired databases for future learning using a histogram of the top 5 databases.

# %% [markdown]
# 目的：上位5つのデータベースのヒストグラムを使用して、将来の学習のために最も望ましいデータベースを視覚化します。

# %%
## Write your code here


QUERY = """
SELECT DatabaseWantToWorkWith, COUNT(*) as count
FROM main
WHERE DatabaseWantToWorkWith IS NOT NULL
GROUP BY DatabaseWantToWorkWith
ORDER BY count DESC
LIMIT 5
"""
df_db = pd.read_sql_query(QUERY, conn)

plt.figure(figsize=(10, 6))
plt.bar(df_db['DatabaseWantToWorkWith'], df_db['count'])
plt.title('Top 5 Most Desired Databases')
plt.xlabel('Database')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **3.2 Histogram of Preferred Work Locations (`RemoteWork`)**

# %% [markdown]
# Objective: Use a histogram to explore the distribution of preferred work arrangements (`remote work`).

# %% [markdown]
# 目的：ヒストグラムを使用して、好みの仕事の取り決め（「リモートワーク」）の分布を調査します。

# %%
## Write your code here

QUERY = """
SELECT RemoteWork, COUNT(*) as count
FROM main
WHERE RemoteWork IS NOT NULL
GROUP BY RemoteWork
"""
df_remote = pd.read_sql_query(QUERY, conn)

plt.figure(figsize=(10, 6))
plt.bar(df_remote['RemoteWork'], df_remote['count'])
plt.title('Distribution of Preferred Work Arrangements')
plt.xlabel('Work Arrangement')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Visualizing Comparison of Data

# %% [markdown]
# **4.1 Histogram of Median CompTotal for Ages 45 to 60**

# %% [markdown]
# Objective: Plot the histogram for `CompTotal` within the age group 45 to 60 to analyze compensation distribution among mid-career respondents.

# %% [markdown]
# 目的：年齢層45〜60歳の「compototal」のヒストグラムをプロットして、中期キャリアの回答者間の補償分布を分析します。

# %%
## Write your code here

QUERY = """
SELECT CompTotal 
FROM main 
WHERE CompTotal IS NOT NULL 
AND Age IN ('45-54 years old', '55-64 years old')
"""
df_mid_career = pd.read_sql_query(QUERY, conn)

plt.figure(figsize=(10, 6))
plt.hist(df_mid_career['CompTotal'], bins=40, edgecolor='black')
plt.title('Distribution of Total Compensation (Ages 45-64)')
plt.xlabel('Total Compensation')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **4.2 Histogram of Job Satisfaction (`JobSat`) by YearsCodePro**

# %% [markdown]
# Objective: Plot the histogram for `JobSat` scores based on respondents' years of professional coding experience.

# %% [markdown]
# 目的：回答者の長年の専門的なコーディングエクスペリエンスに基づいて、「Jobsat」スコアのヒストグラムをプロットします。

# %%
## Write your code here

QUERY = """
SELECT JobSat, YearsCodePro 
FROM main 
WHERE JobSat IS NOT NULL AND YearsCodePro IS NOT NULL
"""
df_job_sat = pd.read_sql_query(QUERY, conn)

plt.figure(figsize=(20, 8))
for job_sat in df_job_sat['JobSat'].unique():
    data = df_job_sat[df_job_sat['JobSat'] == job_sat]['YearsCodePro']
    plt.hist(data, bins=100, alpha=0.5, label=job_sat)

plt.title('Distribution of Years of Experience by Job Satisfaction')
plt.xlabel('Years of Professional Coding')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Final step: Close the database connection

# %% [markdown]
# Once you've completed the lab, make sure to close the connection to the SQLite database:

# %%
conn.close()

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you used histograms to visualize various aspects of the dataset, focusing on:
#
# - Distribution of compensation, coding experience, and work hours.
#
# - Relationships in compensation across age groups and work status.
#
# - Composition of data by desired databases and work environments.
#
# - Comparisons of job satisfaction across years of experience.
#
# Histograms helped reveal patterns and distributions in the data, enhancing your understanding of developer demographics and preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
