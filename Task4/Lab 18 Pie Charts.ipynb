# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
#  - このラボでは、データの視覚化に焦点を当てます。
#
#  - 提供されたデータセットは、分析のためにパンダにロードされます。
#
#  - さまざまなパイチャートが作成されます。
#     - 開発者の好みを分析します。
#
#     - テクノロジーの使用動向を特定します。
#
#  - ラボは、視覚表現を使用して重要な変数に関する洞察を提供することを目的としています。

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
#  - データの分布を視覚化します。
#
#  - 2つの機能間の関係を視覚化します。
#
#  - データの構成を視覚化します。
#
#  - データの比較を視覚化します。

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
url =  'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv(url)

# Display the first few rows to understand the structure of the data
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
pd.set_option('display.max_columns', None)

columms_list = list(df.columns)

columms_list
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Age',
#  'Employment',
#  'RemoteWork',
#  'Check',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'LearnCodeOnline',
#  'TechDoc',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'PurchaseInfluence',
#  'BuyNewTool',
#  'BuildvsBuy',
#  'TechEndorse',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'LanguageAdmired',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'DatabaseAdmired',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'PlatformAdmired',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'WebframeAdmired',
#  'EmbeddedHaveWorkedWith',
#  'EmbeddedWantToWorkWith',
#  'EmbeddedAdmired',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'MiscTechAdmired',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'ToolsTechAdmired',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
# ...

# %%
import seaborn as sns
sns.set_style("darkgrid")
sns.set_palette("pastel")
sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 2.0})

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %% [markdown]
# 調査データでは、 `DatabaseWantToworkWith`列には、回答者が協力したいデータベースがリストされています。
# パイチャートの上位5つの最も提示されたデータベースを視覚化しましょう。

# %%
##Write your code here

# データベースの希望を集計
db_counts = df['DatabaseWantToWorkWith'].value_counts().head(5)

# 円グラフの作成
plt.figure(figsize=(10, 8))
plt.pie(db_counts, labels=db_counts.index, autopct='%1.1f%%')
plt.title('Top 5 Databases Respondents Want to Work With')
plt.axis('equal')
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %% [markdown]
# 「Devtype」列には、回答者の開発者タイプがリストされています。パイチャートで上位5つの開発者の役割を表示して、分布を調べます。

# %%
##Write your code here

# 開発者タイプの集計
dev_counts = df['DevType'].value_counts().head(5)

# 円グラフの作成
plt.figure(figsize=(10, 8))
plt.pie(dev_counts, labels=dev_counts.index, autopct='%1.1f%%')
plt.title('Top 5 Developer Roles')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %% [markdown]
# 「opsysprofessional」の使用列は、オペレーティングシステム開発者が専門的に使用していることを示しています。パイチャートの上部オペレーティングシステムの分布を視覚化しましょう。

# %%
##Write your code here

# プロフェッショナル使用のOS集計
os_counts = df['OpSysProfessional use'].value_counts().head(5)

# 円グラフの作成
plt.figure(figsize=(10, 8))
plt.pie(os_counts, labels=os_counts.index, autopct='%1.1f%%')
plt.title('Top 5 Operating Systems Used Professionally')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %% [markdown]
# 「LanguageHaveworked」列には、回答者が経験しているプログラミング言語が含まれています。パイチャートをプロットして、上位5つの言語の構成を表示します。

# %%
##Write your code here

# 使用経験のある言語の集計
lang_counts = df['LanguageHaveWorkedWith'].value_counts().head(5)

# 円グラフの作成
plt.figure(figsize=(10, 8))
plt.pie(lang_counts, labels=lang_counts.index, autopct='%1.1f%%')
plt.title('Top 5 Programming Languages Worked With')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %% [markdown]
# 「newcollabtoolshaveworked」列を使用して、回答者がプロの仕事で使用するトップコラボレーションツールを特定して視覚化します。

# %%
##Write your code here

# コラボレーションツールの集計
collab_counts = df['NEWCollabToolsHaveWorkedWith'].value_counts().head(5)

# 円グラフの作成
plt.figure(figsize=(10, 8))
plt.pie(collab_counts, labels=collab_counts.index, autopct='%1.1f%%')
plt.title('Top 5 Collaboration Tools Used')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# このタスクでは、調査データの特定の側面を分析するために、追加のパイチャートを作成します。 「Pandas」と「Matplotlib」を使用して、各タスクを完了し、調査結果を解釈します。

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %% [markdown]
# 「Languageadmired」列には、回答者が最も賞賛するプログラミング言語がリストされています。パイチャートを作成して、上位5つの賞賛された言語を視覚化します。

# %%
##Write your code here

# 最も賞賛する言語の集計
admired_counts = df['LanguageAdmired'].value_counts().head(5)

# 円グラフの作成
plt.figure(figsize=(10, 8))
plt.pie(admired_counts, labels=admired_counts.index, autopct='%1.1f%%')
plt.title('Top 5 Most Admired Programming Languages')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %% [markdown]
# 列を使用して「aitoolcurrally」を使用して、パイチャートを作成して、開発者が現在AI開発に使用している上位5つのツールを視覚化します。

# %%
##Write your code here

# AIツールの集計
ai_counts = df['AIToolCurrently Using'].value_counts().head(5)

# 円グラフの作成
plt.figure(figsize=(10, 8))
plt.pie(ai_counts, labels=ai_counts.index, autopct='%1.1f%%')
plt.title('Top 5 AI Development Tools Currently Used')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %% [markdown]
# `webframewanttoworkwith`列には、回答者が作業に関心を持っているWebフレームワークが含まれています。
# パイチャートの上位5つのフレームワークを視覚化します。

# %%
##Write your code here

# Webフレームワークの集計
web_counts = df['WebframeWantToWorkWith'].value_counts().head(5)

# 円グラフの作成
plt.figure(figsize=(10, 8))
plt.pie(web_counts, labels=web_counts.index, autopct='%1.1f%%')
plt.title('Top 5 Preferred Web Frameworks')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %% [markdown]
# 「EmbeddedWantToworkWith」列を使用して、パイチャートを作成して、回答者が協力したい上位5の最も望ましい埋め込みテクノロジーを表示します。

# %%
##Write your code here

# 組み込み技術の集計
embedded_counts = df['EmbeddedWantToWorkWith'].value_counts().head(5)

# 円グラフの作成
plt.figure(figsize=(10, 8))
plt.pie(embedded_counts, labels=embedded_counts.index, autopct='%1.1f%%')
plt.title('Top 5 Most Desired Embedded Technologies')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
